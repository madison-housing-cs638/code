# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt

COMMON_DIR = os.path.join(os.pardir, 'common')
sys.path.insert(1, COMMON_DIR)

import data_retreiver
print(dir(data_retreiver))
# Out:
# ['DATASETS', 'DATA_PATH', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'download_datasets', 'download_file', 'load_csv_datasets', 'os', 'pd', 'urllib3']

# %%
data_retreiver.download_datasets()

# %%
(assessments, names) = data_retreiver.load_csv_datasets("all_parcel_assessments", "all_parcel_names")
assessments
# Out:
#             Parcel  Year  Land_Assessment  Improvement_Assessment  \
# 0                0  2020                0                       0
# 1      60802307997  2019                0                    5000
# 2      70835124359  2019              500                    1500
# 3      60802112023  2019            86200                  201200
# 4      70813307183  2019           114200                  267200
# ...            ...   ...              ...                     ...
# 80062  81028119320  2019             8700                   67000
# 80063  70816324019  2019            94000                  348800
# 80064  80924427043  2019             8600                  166800
# 80065  70833119154  2019                0                       0
# 80066  70923413987  2019                0                    5000
#
#        Total_Assessment
# 0                     0
# 1                  5000
# 2                  2000
# 3                287400
# 4                381400
# ...

# %%
all_values = assessments["Total_Assessment"].values
fig, ax = plt.subplots()
ax.set_title("This is a really shitty histogram of assessment values")
ax.set_xlim(0, 2000000)
ax.hist(all_values, bins=1000)
print()
